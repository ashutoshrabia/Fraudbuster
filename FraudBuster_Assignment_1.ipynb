# %% [markdown]
# <a href="https://colab.research.google.com/github/ashutoshrabia/Fraudbuster/blob/main/FraudBuster_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Ashutosh*** ***Rabia***
# # ***220238***

# %% [markdown]
# ### House Pricing Dataset
# This dataset contains various features or attributes related to a house, such as its size, number of rooms, amenities.\
# The goal is to use the dataset to build a model that can predict the price of
# a house based on its features.\
# This assignment is based on EDA of the dataset.\
# https://drive.google.com/file/d/11zaqBkMq-J02u4j58oUbp0K2m_1C9MEI/view?usp=sharing

# %% [markdown]
# **INSTRUCTIONS:**
#
# Go to File -> Save a Copy in Drive and edit this notebook in your copy
#
# Write your code in following code cells
#
# Put all your doubts on Discord channel
#
# Marks will not be given if the code is plagiarised
#
# You can refer to prev class notebook (Fraudbuster_01)
#
# Total marks : 75

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###1. Read data (1 Marks)

# %%
df = pd.read_csv('Housing.csv')

# %% [markdown]
# ###2. Display top 10 rows and bottom 10 rows of the dataset (1 Marks)

# %%
df.head(10),df.tail(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ccdbd86f53c3> in <cell line: 1>()
# ----> 1 df.head(10),df.tail(10)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ###3. Display shape of dataset (1 Marks)

# %%
df.shape
# Out:
# (545, 13)

# %% [markdown]
# ###4. Display data types of all columns (1 Marks)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# ###5. Find stats of all columns (1 Marks)

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# ###6. Name which columns are features and which is target variable (5 Marks)

# %%
target = df.iloc[:,0:1]
features = df.iloc[:,1:13]

# %% [markdown]
# ###7. Of the 12 features differentiate numerical and categorical features (5 Marks)
# hint: Print unique rows for each feature

# %%
numerical = features.iloc[:,0:10]
numerical.drop(numerical.iloc[:,4:9], inplace=True,axis=1)
numerical
# Out:
#      area  bedrooms  bathrooms  stories  parking
# 0    7420         4          2        3        2
# 1    8960         4          4        4        3
# 2    9960         3          2        2        2
# 3    7500         4          2        2        3
# 4    7420         4          1        2        2
# ..    ...       ...        ...      ...      ...
# 540  3000         2          1        1        2
# 541  2400         3          1        1        0
# 542  3620         2          1        1        0
# 543  2910         3          1        1        0
# 544  3850         3          1        2        0
#
# [545 rows x 5 columns]

# %%
categorical = features.iloc[:,4:12]
categorical.drop(categorical.iloc[:,5:6],inplace=True, axis=1)
categorical
# Out:
#     mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# 0        yes        no       no              no             yes      yes
# 1        yes        no       no              no             yes       no
# 2        yes        no      yes              no              no      yes
# 3        yes        no      yes              no             yes      yes
# 4        yes       yes      yes              no             yes       no
# ..       ...       ...      ...             ...             ...      ...
# 540      yes        no      yes              no              no       no
# 541       no        no       no              no              no       no
# 542      yes        no       no              no              no       no
# 543       no        no       no              no              no       no
# 544      yes        no       no              no              no       no
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# 2     semi-furnished
# 3          furnished
# 4          furnished
# ..               ...
# 540      unfurnished
# 541   semi-furnished
# 542      unfurnished
# 543        furnished
# 544      unfurnished
#
# [545 rows x 7 columns]

# %% [markdown]
# ###8. Find Null or Missing values in the dataset (5 Marks)

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ###9. Plot the distribution of target variable : *'price'*. (5 Marks)

# %%
df.price.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ###10. Find and Plot the categorical features against there count in dataset (25 Marks)
# hint: Find the count of rows for each unique value of a feature and then plot

# %%
df1 = df.pivot_table(index = ['mainroad'], aggfunc ='size')

df2 = df.pivot_table(index = ['guestroom'], aggfunc ='size')

df3 = df.pivot_table(index = ['basement'], aggfunc ='size')

df4 = df.pivot_table(index = ['hotwaterheating'], aggfunc ='size')

df5 = df.pivot_table(index = ['airconditioning'], aggfunc ='size')

df6 = df.pivot_table(index = ['prefarea'], aggfunc ='size')

df7 = df.pivot_table(index = ['furnishingstatus'], aggfunc ='size')

y=[df1.no , df1.yes, df2.no , df2.yes, df3.no , df3.yes, df4.no , df4.yes, df5.no , df5.yes, df6.no , df6.yes, df7.furnished, df7['semi-furnished'], df7.unfurnished]
x=['mainroad(no)','mainroad(yes)','guest(no)','guest(yes)','basement(no)','basement(yes)','hotwater(no)','hotwater(yes)','AC(no)','AC(yes)','prefarea(no)','prefarea(yes)','furnished','semi-fur','unfurnished']

f = plt.figure()
f.set_figwidth(20)
plt.plot(x,y)

#fig, ax = plt.subplots()

#ax.set_figwidth(20)
#ax.stem(x,y)


#ax.set( xticks=np.arange(0, 15))

#plt.show()

# %% [markdown]
# ##11. Box-Plot for the numerical feature (5 Marks)

# %%
sns.boxplot(numerical)
plt.show()

# %% [markdown]
# ###12. Check for duplicate rows in the dataset (5 Marks)

# %%
duplicate = df[df.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [price, area, bedrooms, bathrooms, stories, mainroad, guestroom, basement, hotwaterheating, airconditioning, parking, prefarea, furnishingstatus]
# Index: []

# %% [markdown]
# ###13. Display Rows with *'area'* of house in range [7000, 7500] (5 Marks)

# %%
df[df['area'].between(6999,7501)]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# 5    10850000  7500         3          3        1      yes        no      yes
# 21    8680000  7155         3          2        1      yes       yes      yes
# 30    8400000  7475         3          2        4      yes        no       no
# 31    8400000  7000         3          1        4      yes        no       no
# 35    8080940  7000         3          2        4      yes        no       no
# 36    8043000  7482         3          2        3      yes        no       no
# 49    7420000  7440         3          2        1      yes       yes      yes
# 50    7420000  7440         3          2        4      yes        no       no
# 88    6475000  7410         3          1        1      yes       yes      yes
# 93    6300000  7200         3          2        1      yes        no      yes
# 119   5950000  7020         3          1        1      yes        no      yes
# 121   5950000  7231         3          1        2      yes       yes      yes
# 123   5950000  7320         4          2        2      yes        no       no
# 126   5880000  7160         3          1        1      yes        no      yes
# 134   5803000  7000         3          1        1      yes        no      yes
# 178   5229000  7085         3          1        1      yes       yes      yes
# 181   5215000  7200         3          1        2      yes       yes      yes
# 219   4795000  7000         3          1        2      yes        no      yes
# 299   4200000  7000         3          1        1      yes        no       no
# 331   3920000  7260         3          2        1      yes       yes      yes
# 342   3850000  7152         3          1        2      yes        no       no
# 393   3500000  7424         3          1        1       no        no       no
# 399   3500000  7350         2          1        1      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# 5                no             yes        2      yes   semi-furnished
# 21               no             yes        2       no      unfurnished
# 30               no             yes        2       no      unfurnished
# 31               no             yes        2       no   semi-furnished
# 35               no             yes        2       no        furnished
# 36              yes              no        1      yes        furnished
# 49               no             yes        0      yes   semi-furnished
# 50               no              no        1      yes      unfurnished
# 88               no             yes        2      yes      unfurnished
# 93               no             yes        3       no   semi-furnished
# 119              no             yes        2      yes   semi-furnished
# 121              no             yes        0      yes   semi-furnished
# 123              no              no        0       no        furnished
# 126              no              no        2      yes      unfurnished
# 134              no              no        2      yes   semi-furnished
# 178              no              no        2      yes   semi-furnished
# 181              no              no        1      yes        furnished
# 219              no              no        0       no      unfurnished
# 299              no              no        3       no        furnished
# 331              no              no        3       no        furnished
# 342              no             yes        0       no        furnished
# 393              no              no        0       no      unfurnished
# 399              no              no        1       no   semi-furnished

# %% [markdown]
# ###14. Price of house with largest area (5 Marks)

# %%
print(df.max().price)
# Out:
# 13300000

# %% [markdown]
# ###15. Plot a Scatter plot between *'price'* and *'area'* (5 Marks)

# %%
plt.scatter(df['parking'],df['area'], marker='*')
plt.show()
